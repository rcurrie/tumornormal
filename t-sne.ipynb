# %%
import numpy as np
import pandas as pd

# %%
with h5py.File('data/tumor_normal.h5', 'r') as f:
    X = f['X_train'][:].astype(np.float64)
    classes = f['classes_train'][:]

# %%
# !pip3 install git+https://github.com/DmitryUlyanov/Multicore-TSNE.git
# Out:
# Collecting git+https://github.com/DmitryUlyanov/Multicore-TSNE.git
#   Cloning https://github.com/DmitryUlyanov/Multicore-TSNE.git to /tmp/pip-ptadj6u8-build
#   Requirement already satisfied (use --upgrade to upgrade): MulticoreTSNE==0.1 from git+https://github.com/DmitryUlyanov/Multicore-TSNE.git in /opt/conda/lib/python3.5/site-packages
# Requirement already satisfied: numpy in /opt/conda/lib/python3.5/site-packages (from MulticoreTSNE==0.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.5/site-packages (from MulticoreTSNE==0.1)
# Requirement already satisfied: cffi in /opt/conda/lib/python3.5/site-packages (from MulticoreTSNE==0.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.5/site-packages (from cffi->MulticoreTSNE==0.1)

# %%
# %%time
from MulticoreTSNE import MulticoreTSNE as TSNE

tsne = TSNE(n_jobs=16)
Y = tsne.fit_transform(X)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))
plt.scatter(Y[:,0], Y[:,1], s=6, marker='o', linewidth=0, c=classes)
plt.show()
